# %%
dbutils.fs.rm("dbfs:/pipelines/b4bf3683-0d3c-44b4-b0a5-d05d64a3cb3f/", recurse=True)

# %%
import subprocess
result = spark.sql("DESCRIBE PIPELINE 'b4bf3683-0d3c-44b4-b0a5-d05d64a3cb3f' ")
result.show(truncate=False)
