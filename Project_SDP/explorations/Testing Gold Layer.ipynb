-- %%
select * from declarative_catalog.gold.dimartist

-- %%
select * from declarative_catalog.gold.dimdate

-- %%
select * from declarative_catalog.gold.dimtrack

-- %%
select * from declarative_catalog.gold.dimuser

-- %%
select * from declarative_catalog.gold.facttstream

-- %%
select * from declarative_catalog.gold.obt
