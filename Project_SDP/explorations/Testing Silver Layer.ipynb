-- %%
select * from declarative_catalog.silver.silver_user

-- %%
select * from declarative_catalog.silver.silver_artist

-- %%
select * from declarative_catalog.silver.silver_date

-- %%
select * from declarative_catalog.silver.silver_track

-- %%
select * from declarative_catalog.silver.silver_fact

-- %%
select * from declarative_catalog.gold.dimfact
