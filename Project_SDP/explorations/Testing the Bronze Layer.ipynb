-- %%
select * from declarative_catalog.bronze.bronze_user

-- %%
select * from declarative_catalog.bronze.bronze_artist

-- %%
select * from declarative_catalog.bronze.bronze_track
order by track_id

-- %%
select * from declarative_catalog.bronze.bronze_date

-- %%
select * from declarative_catalog.bronze.bronze_fact
